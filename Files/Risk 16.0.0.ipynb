# %% [markdown]
# # **Libraries**

# %%
import pandas as pd
import numpy as np

from feature_engine.selection import DropCorrelatedFeatures
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

import lightgbm as lgb
from sklearn.metrics import roc_auc_score

from feature_engine.encoding import WoEEncoder
from feature_engine.imputation import CategoricalImputer
from feature_engine.imputation import ArbitraryNumberImputer

import functions
import importlib
importlib.reload(functions)

import warnings

# %% [markdown]
# # **Display**

# %%
# %matplotlib inline

pd.options.display.max_rows = 300000
pd.options.display.max_columns = 999
pd.options.display.max_colwidth = 500

warnings.filterwarnings("ignore")
warnings.simplefilter(action="ignore", category=FutureWarning)

pd.set_option('display.max_rows', 200)

size = 20

# %% [markdown]
# # **Load Data**

# %%
train = pd.read_csv(
    r"C:\Users\Dell\Documents\AI\Risk\Data\application_train.csv",
    index_col=False
)


test = pd.read_csv(
    r"C:\Users\Dell\Documents\AI\Risk\Data\application_test.csv",
    index_col=False
)

# %% [markdown]
# # **Variables**

# %%
random_state = 101
target = 'TARGET'

# %% [markdown]
# ## **Remove Empty Features**

# %%
list_columns = functions.check_columns_with_one_uniquevalue(test)

# %%
train = train.drop(list_columns, axis = 1)

# %% [markdown]
# ## **Reduce Memory Usage**

# %%
train = functions.reduce_memory_usage(train)
# Out:
# Memory usage of dataframe is 260.42 MB
# Memory usage after optimization is: 89.15 MB
# Decreased by 65.8%

# %% [markdown]
# # **Data Cleaning**

# %%
train = train[train['CODE_GENDER'] != 'XNA']
train['DAYS_EMPLOYED'][train['DAYS_EMPLOYED'] == 365243] = np.nan

# %% [markdown]
# # **Feature Engineering**

# %% [markdown]
# ## **Days Birth to Age in Years**

# %%
train["DAYS_BIRTH"] = abs(train["DAYS_BIRTH"])
train["DAYS_BIRTH"] = train["DAYS_BIRTH"]/365
train.rename(columns={'DAYS_BIRTH': 'Age'}, inplace=True)
train["Age"].describe()
# Out:
# count    307507.000000
# mean         43.937061
# std          11.956116
# min          20.517808
# 25%          34.008219
# 50%          43.150685
# 75%          53.923288
# max          69.120548
# Name: Age, dtype: float64

# %% [markdown]
# ## **Days Employed to Years Employed**

# %%
train["DAYS_EMPLOYED"] = abs(train["DAYS_EMPLOYED"])
train["DAYS_EMPLOYED"] = train["DAYS_EMPLOYED"]/365
train.rename(columns={"DAYS_EMPLOYED": 'YEARS_EMPLOYED'}, inplace=True)
train["YEARS_EMPLOYED"].describe()
# Out:
# count    252133.000000
# mean          6.531897
# std           6.406377
# min           0.000000
# 25%           2.101370
# 50%           4.515068
# 75%           8.698630
# max          49.073973
# Name: YEARS_EMPLOYED, dtype: float64

# %% [markdown]
# ## **Days ID Published to Years ID Published**

# %%
train["DAYS_ID_PUBLISH"] = abs(train["DAYS_ID_PUBLISH"])
train["DAYS_ID_PUBLISH"] = train["DAYS_ID_PUBLISH"]/365
train.rename(columns={"DAYS_ID_PUBLISH": 'YEARS_ID_PUBLISH'}, inplace=True)
train["YEARS_ID_PUBLISH"].describe()
# Out:
# count    307507.000000
# mean          8.203292
# std           4.135492
# min           0.000000
# 25%           4.712329
# 50%           8.915068
# 75%          11.778082
# max          19.717808
# Name: YEARS_ID_PUBLISH, dtype: float64

# %% [markdown]
# ## **Days Registration to Years Registration**

# %%
train["DAYS_REGISTRATION"] = abs(train["DAYS_REGISTRATION"])
train["DAYS_REGISTRATION"] = train["DAYS_REGISTRATION"]/365
train.rename(columns={"DAYS_REGISTRATION": 'YEARS_REGISTRATION'}, inplace=True)
train["YEARS_REGISTRATION"].describe()
# Out:
# count    307507.000000
# mean               NaN
# std           0.000000
# min           0.000000
# 25%           5.507812
# 50%          12.335938
# 75%          20.500000
# max          67.625000
# Name: YEARS_REGISTRATION, dtype: float64

# %% [markdown]
# ## **Days Last Phone Change to Years Last Phone Change**

# %%
train["DAYS_LAST_PHONE_CHANGE"] = abs(train["DAYS_LAST_PHONE_CHANGE"])
train["DAYS_LAST_PHONE_CHANGE"] = train["DAYS_LAST_PHONE_CHANGE"]/365
train.rename(columns={"DAYS_LAST_PHONE_CHANGE": 'YEARS_LAST_PHONE_CHANGE'}, inplace=True)
train["YEARS_LAST_PHONE_CHANGE"].describe()
# Out:
# count    307506.000000
# mean               NaN
# std           0.000000
# min           0.000000
# 25%           0.750488
# 50%           2.074219
# 75%           4.300781
# max          11.757812
# Name: YEARS_LAST_PHONE_CHANGE, dtype: float64

# %% [markdown]
# ## **Percentage of Credit Amount Relative to Client's Income**

# %%
train['CREDIT_INCOME_PERCENT'] = train['AMT_CREDIT'] / train['AMT_INCOME_TOTAL']

# %% [markdown]
# ## **Percentage of the Loan Annuity Relative to a Client's Income**

# %%
train['ANNUITY_INCOME_PERCENT'] = train['AMT_ANNUITY'] / train['AMT_INCOME_TOTAL']

# %% [markdown]
# ## **Length of the Payment in Months**

# %%
train['CREDIT_TERM'] = train['AMT_ANNUITY'] / train['AMT_CREDIT']

# %% [markdown]
# ## **Percentage of the Days Employed Relative to the Client's Age**

# %%
train['YEARS_EMPLOYED_PERCENT'] = train['YEARS_EMPLOYED'] / train['Age']

# %% [markdown]
# # **Missing Values**

# %%
functions.MissingValues(train)
# Out:
#                               NumberMissing  PercentageMissing DataType
# COMMONAREA_MEDI                      214862              69.87  float16
# COMMONAREA_MODE                      214862              69.87  float16
# COMMONAREA_AVG                       214862              69.87  float16
# NONLIVINGAPARTMENTS_MODE             213512              69.43  float16
# NONLIVINGAPARTMENTS_MEDI             213512              69.43  float16
# NONLIVINGAPARTMENTS_AVG              213512              69.43  float16
# FONDKAPREMONT_MODE                   210293              68.39   object
# LIVINGAPARTMENTS_MEDI                210197              68.36  float16
# LIVINGAPARTMENTS_MODE                210197              68.36  float16
# LIVINGAPARTMENTS_AVG                 210197              68.36  float16
# FLOORSMIN_MODE                       208640              67.85  float16
# FLOORSMIN_AVG                        208640              67.85  float16
# FLOORSMIN_MEDI                       208640              67.85  float16
# YEARS_BUILD_MEDI                     204486              66.50  float16
# YEARS_BUILD_AVG                      204486              66.50  float16
# YEARS_BUILD_MODE                     204486              66.50  float16
# OWN_CAR_AGE                          202927              65.99  float16
# LANDAREA_MODE                        182588              59.38  float16
# LANDAREA_MEDI                        182588              59.38  float16
# LANDAREA_AVG                         182588              59.38  float16
# BASEMENTAREA_MODE                    179942              58.52  float16
# BASEMENTAREA_AVG                     179942              58.52  float16
# BASEMENTAREA_MEDI                    179942              58.52  float16
# EXT_SOURCE_1                         173376              56.38  float16
# NONLIVINGAREA_AVG                    169680              55.18  float16
# NONLIVINGAREA_MODE                   169680              55.18  float16
# NONLIVINGAREA_MEDI                   169680              55.18  float16
# ELEVATORS_MEDI                       163890              53.30  float16
# ELEVATORS_MODE                       163890              53.30  float16
# ELEVATORS_AVG                        163890              53.30  float16
# WALLSMATERIAL_MODE                   156340              50.84   object
# APARTMENTS_MEDI                      156060              50.75  float16
# APARTMENTS_MODE                      156060              50.75  float16
# APARTMENTS_AVG                       156060              50.75  float16
# ENTRANCES_MODE                       154827              50.35  float16
# ENTRANCES_AVG                        154827              50.35  float16
# ENTRANCES_MEDI                       154827              50.35  float16
# LIVINGAREA_MEDI                      154349              50.19  float16
# LIVINGAREA_AVG                       154349              50.19  float16
# LIVINGAREA_MODE                      154349              50.19  float16
# HOUSETYPE_MODE                       154296              50.18   object
# FLOORSMAX_AVG                        153019              49.76  float16
# FLOORSMAX_MODE                       153019              49.76  float16
# FLOORSMAX_MEDI                       153019              49.76  float16
# YEARS_BEGINEXPLUATATION_MEDI         150006              48.78  float16
# YEARS_BEGINEXPLUATATION_MODE         150006              48.78  float16
# YEARS_BEGINEXPLUATATION_AVG          150006              48.78  float16
# TOTALAREA_MODE                       148430              48.27  float16
# EMERGENCYSTATE_MODE                  145754              47.40   object
# OCCUPATION_TYPE                       96389              31.35   object
# EXT_SOURCE_3                          60965              19.83  float16
# YEARS_EMPLOYED                        55374              18.01  float64
# YEARS_EMPLOYED_PERCENT                55374              18.01  float64
# AMT_REQ_CREDIT_BUREAU_YEAR            41519              13.50  float16
# AMT_REQ_CREDIT_BUREAU_HOUR            41519              13.50  float16
# AMT_REQ_CREDIT_BUREAU_WEEK            41519              13.50  float16
# AMT_REQ_CREDIT_BUREAU_MON             41519              13.50  float16
# AMT_REQ_CREDIT_BUREAU_DAY             41519              13.50  float16
# AMT_REQ_CREDIT_BUREAU_QRT             41519              13.50  float16
# NAME_TYPE_SUITE                        1292               0.42   object
# DEF_60_CNT_SOCIAL_CIRCLE               1021               0.33  float16
# OBS_60_CNT_SOCIAL_CIRCLE               1021               0.33  float16
# OBS_30_CNT_SOCIAL_CIRCLE               1021               0.33  float16
# DEF_30_CNT_SOCIAL_CIRCLE               1021               0.33  float16
# EXT_SOURCE_2                            660               0.21  float16
# AMT_GOODS_PRICE                         278               0.09  float32
# AMT_ANNUITY                              12               0.00  float32
# CNT_FAM_MEMBERS                           2               0.00  float16
# YEARS_LAST_PHONE_CHANGE                   1               0.00  float16
# ANNUITY_INCOME_PERCENT                   12               0.00  float32
# CREDIT_TERM                              12               0.00  float32

# %% [markdown]
# ## **Imputation**

# %%
ani = ArbitraryNumberImputer(arbitrary_number=-99999)
ani.fit(train)
train = ani.transform(train)

# %%
ci = CategoricalImputer(imputation_method='missing', fill_value='UNKNOWN')
ci.fit(train)
train = ci.transform(train)

# %% [markdown]
# ## **WoE Encoder**

# %%
woe = WoEEncoder(fill_value=0.0001)
woe.fit(train, train[target])
train = woe.transform(train)

# %% [markdown]
# ## **Train Test Split**

# %%
X = train.drop('TARGET', axis=1)
y = train['TARGET']

X, y = shuffle(X, y, random_state=random_state)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=random_state)

# %% [markdown]
# ### **LGBM**

# %%
model = lgb.LGBMClassifier(boosting_type='gbdt', 
                           num_leaves=31, 
                           max_depth=-1, 
                           learning_rate=0.1, 
                           n_estimators=100,
                           verbose=-1)

model.fit(X_train, y_train)

y_prob = model.predict_proba(X_test)[:, 1]  

auc_score = roc_auc_score(y_test, y_prob)
print(f"AUC Score: {auc_score:.2f}")
# Out:
# AUC Score: 0.76

# %% [markdown]
# ## **Feature Importance**

# %%
feature_importance = model.feature_importances_
feature_names = X.columns

importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importance})
importance_df = importance_df.sort_values(by='Importance', ascending=False)

importance_df

# %% [markdown]
# ## **Keep Columns**

# %%
columns = ['CREDIT_TERM',
                   'EXT_SOURCE_3',
                   'EXT_SOURCE_1',
                   'EXT_SOURCE_2',
                   'YEARS_ID_PUBLISH',
                   'AMT_ANNUITY', 
                   'AMT_GOODS_PRICE', 
                   'YEARS_EMPLOYED_PERCENT',
                   'YEARS_EMPLOYED',
                   'ORGANIZATION_TYPE',
                   'AMT_CREDIT',
                   'YEARS_REGISTRATION',
                   'YEARS_LAST_PHONE_CHANGE',
                   'ANNUITY_INCOME_PERCENT',
                   'CREDIT_INCOME_PERCENT',
                   'OCCUPATION_TYPE',
                   'OWN_CAR_AGE',
                   'CODE_GENDER',
                   'REGION_POPULATION_RELATIVE',
                   'TARGET'] 
train = train[columns]

# %%
train.head()
# Out:
#    CREDIT_TERM  EXT_SOURCE_3  EXT_SOURCE_1  EXT_SOURCE_2  YEARS_ID_PUBLISH  \
# 0     0.060749      0.139404      0.083008      0.262939          5.808219
# 1     0.027598          -inf      0.311279      0.622070          0.797260
# 2     0.050000      0.729492          -inf      0.556152          6.934247
# 3     0.094941          -inf          -inf      0.650391          6.676712
# 4     0.042623          -inf          -inf      0.322754          9.473973
#
#    AMT_ANNUITY  AMT_GOODS_PRICE  YEARS_EMPLOYED_PERCENT  YEARS_EMPLOYED  \
# 0      24700.5         351000.0                0.067329        1.745205
# 1      35698.5        1129500.0                0.070862        3.254795
# 2       6750.0         135000.0                0.011814        0.616438
# 3      29686.5         297000.0                0.159905        8.326027
# 4      21865.5         513000.0                0.152418        8.323288
#
#    ORGANIZATION_TYPE  AMT_CREDIT  YEARS_REGISTRATION  YEARS_LAST_PHONE_CHANGE  \
# 0           0.154884    406597.5            9.992188                 3.107422
# 1          -0.334278   1293502.5            3.250000                 2.267578
# 2          -0.157589    135000.0           11.671875                 2.232422
# 3           0.154884    312682.5           26.937500                 1.690430
# 4          -0.340117    513000.0           11.812500                 3.029297
#
#    ANNUITY_INCOME_PERCENT  CREDIT_INCOME_PERCENT  OCCUPATION_TYPE  \
# 0                0.121978               2.007889         0.297962
# 1                0.132217               4.790750        -0.266369
# 2                0.100000               2.000000         0.297962
# 3                0.219900               2.316167         0.297962
# 4                0.179963               4.222222        -0.266369
#
#    OWN_CAR_AGE  CODE_GENDER  REGION_POPULATION_RELATIVE  TARGET
# 0         -inf     0.250917                    0.018799       1
# 1         -inf    -0.154321                    0.003542       0
# 2         26.0     0.250917                    0.010033       0
# 3         -inf    -0.154321                    0.008018       0
# 4         -inf     0.250917                    0.028656       0

# %% [markdown]
# ### **LGBM**

# %%
X = train.drop('TARGET', axis=1)
y = train['TARGET']

X, y = shuffle(X, y, random_state=random_state)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=random_state)

# %%
model = lgb.LGBMClassifier(boosting_type='gbdt', 
                           num_leaves=31, 
                           max_depth=-1, 
                           learning_rate=0.1, 
                           n_estimators=100,
                           verbose=-1)

model.fit(X_train, y_train)

y_prob = model.predict_proba(X_test)[:, 1]  

auc_score = roc_auc_score(y_test, y_prob)
print(f"AUC Score: {auc_score:.2f}")
# Out:
# AUC Score: 0.76

# %% [markdown]
# ## **Feature Importance**

# %%
# Get feature importance and sort by importance
feature_importance = model.feature_importances_
feature_names = X.columns

# Create a DataFrame to hold feature importance values
importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importance})
importance_df = importance_df.sort_values(by='Importance', ascending=False)

importance_df
# Out:
#                        Feature  Importance
# 0                  CREDIT_TERM         460
# 1                 EXT_SOURCE_3         271
# 3                 EXT_SOURCE_2         248
# 2                 EXT_SOURCE_1         218
# 4             YEARS_ID_PUBLISH         177
# 5                  AMT_ANNUITY         156
# 6              AMT_GOODS_PRICE         148
# 11          YEARS_REGISTRATION         147
# 12     YEARS_LAST_PHONE_CHANGE         132
# 13      ANNUITY_INCOME_PERCENT         132
# 8               YEARS_EMPLOYED         128
# 9            ORGANIZATION_TYPE         126
# 10                  AMT_CREDIT         126
# 7       YEARS_EMPLOYED_PERCENT         121
# 16                 OWN_CAR_AGE         105
# 18  REGION_POPULATION_RELATIVE          99
# 14       CREDIT_INCOME_PERCENT          93
# 15             OCCUPATION_TYPE          70
# 17                 CODE_GENDER          43
