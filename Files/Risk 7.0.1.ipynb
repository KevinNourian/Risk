# %% [markdown]
# # **Libraries**

# %%
import pandas as pd
import numpy as np

from feature_engine.selection import DropCorrelatedFeatures
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

import lightgbm as lgb
from sklearn.metrics import roc_auc_score

from feature_engine.encoding import WoEEncoder

import functions
import importlib
importlib.reload(functions)

import time

import warnings

# %% [markdown]
# # **Display**

# %%
# %matplotlib inline

pd.options.display.max_rows = 300000
pd.options.display.max_columns = 999
pd.options.display.max_colwidth = 500

warnings.filterwarnings("ignore")
warnings.simplefilter(action="ignore", category=FutureWarning)

pd.set_option('display.max_rows', 200)

size = 20

# %% [markdown]
# # **Data**

# %% [markdown]
# ## **Load Data**

# %%
app_train = pd.read_csv(
    r"C:\Users\Dell\Documents\AI\Risk\Data\application_train.csv",
    index_col=False
)

app_test = pd.read_csv(
    r"C:\Users\Dell\Documents\AI\Risk\Data\application_test.csv",
    index_col=False
)

# %% [markdown]
# # **Variables**

# %%
data = app_train.copy()
random_state = 101
target = 'TARGET'

# %% [markdown]
# ## **Remove Empty Features**

# %%
list_columns = functions.check_columns_with_one_uniquevalue(app_test)

# %%
data = data.drop(list_columns, axis = 1)

# %% [markdown]
# ## **Drop Collinear Features**

# %%
dcf = DropCorrelatedFeatures(threshold=0.7)
data = dcf.fit_transform(data)

# %% [markdown]
# ## **Drop Unneeded Features**

# %%
data.drop('SK_ID_CURR', axis=1, inplace=True)

# %% [markdown]
# ## **Reduce Memory Usage**

# %%
data = functions.reduce_memory_usage(data)
# Out:
# Memory usage of dataframe is 159.54 MB
# Memory usage after optimization is: 63.35 MB
# Decreased by 60.3%

# %% [markdown]
# ## **Missing Values**

# %%
functions.MissingValues(data)
# Out:
#                              NumberMissing  PercentageMissing
# COMMONAREA_AVG                      214865              69.87
# NONLIVINGAPARTMENTS_AVG             213514              69.43
# FONDKAPREMONT_MODE                  210295              68.39
# YEARS_BUILD_AVG                     204488              66.50
# OWN_CAR_AGE                         202929              65.99
# LANDAREA_AVG                        182590              59.38
# BASEMENTAREA_AVG                    179943              58.52
# EXT_SOURCE_1                        173378              56.38
# NONLIVINGAREA_AVG                   169682              55.18
# WALLSMATERIAL_MODE                  156341              50.84
# APARTMENTS_AVG                      156061              50.75
# ENTRANCES_AVG                       154828              50.35
# HOUSETYPE_MODE                      154297              50.18
# FLOORSMAX_AVG                       153020              49.76
# YEARS_BEGINEXPLUATATION_AVG         150007              48.78
# EMERGENCYSTATE_MODE                 145755              47.40
# OCCUPATION_TYPE                      96391              31.35
# EXT_SOURCE_3                         60965              19.83
# AMT_REQ_CREDIT_BUREAU_QRT            41519              13.50
# AMT_REQ_CREDIT_BUREAU_HOUR           41519              13.50
# AMT_REQ_CREDIT_BUREAU_MON            41519              13.50
# AMT_REQ_CREDIT_BUREAU_DAY            41519              13.50
# AMT_REQ_CREDIT_BUREAU_YEAR           41519              13.50
# AMT_REQ_CREDIT_BUREAU_WEEK           41519              13.50
# NAME_TYPE_SUITE                       1292               0.42
# OBS_30_CNT_SOCIAL_CIRCLE              1021               0.33
# DEF_30_CNT_SOCIAL_CIRCLE              1021               0.33
# EXT_SOURCE_2                           660               0.21
# AMT_ANNUITY                             12               0.00
# DAYS_LAST_PHONE_CHANGE                   1               0.00

# %%
num_value = -99999

for col in data.select_dtypes(include=['float16', 'float32', 'float64']).columns:
    data[col].fillna(num_value, inplace=True)

# %%
cat_value = 'UNKNOWN'

for col in data.select_dtypes(include=['object']).columns:
    data[col].fillna(cat_value, inplace=True)

# %% [markdown]
# ## **WoE Encoder**

# %%
woe = WoEEncoder(fill_value=0.0001)
woe.fit(data, data[target])
data = woe.transform(data)

# %% [markdown]
# ## **Train Test Split**

# %%
X = data.drop('TARGET', axis=1)
y = data['TARGET']

X, y = shuffle(X, y, random_state=random_state)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=random_state)

# %% [markdown]
# ### **LGBM**

# %%
model = lgb.LGBMClassifier(boosting_type='gbdt', 
                           num_leaves=31, 
                           max_depth=-1, 
                           learning_rate=0.1, 
                           n_estimators=100,
                           verbose=-1)

model.fit(X_train, y_train)

y_prob = model.predict_proba(X_test)[:, 1]  

auc_score = roc_auc_score(y_test, y_prob)
print(f"AUC Score: {auc_score:.2f}")
# Out:
# AUC Score: 0.75

# %% [markdown]
# ## **Feature Importance**

# %%
# Get feature importance and sort by importance
feature_importance = model.feature_importances_
feature_names = X.columns

# Create a DataFrame to hold feature importance values
importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importance})
importance_df = importance_df.sort_values(by='Importance', ascending=False)

importance_df
# Out:
#                         Feature  Importance
# 34                 EXT_SOURCE_3         256
# 33                 EXT_SOURCE_2         239
# 32                 EXT_SOURCE_1         229
# 13                   DAYS_BIRTH         209
# 6                   AMT_ANNUITY         156
# 14                DAYS_EMPLOYED         150
# 16              DAYS_ID_PUBLISH         143
# 51       DAYS_LAST_PHONE_CHANGE         112
# 31            ORGANIZATION_TYPE         101
# 15            DAYS_REGISTRATION         101
# 5              AMT_INCOME_TOTAL          90
# 12   REGION_POPULATION_RELATIVE          72
# 17                  OWN_CAR_AGE          66
# 23              OCCUPATION_TYPE          65
# 26      HOUR_APPR_PROCESS_START          60
# 9           NAME_EDUCATION_TYPE          56
# 1                   CODE_GENDER          48
# 42                 LANDAREA_AVG          42
# 39               COMMONAREA_AVG          42
# 35               APARTMENTS_AVG          40
# 50     DEF_30_CNT_SOCIAL_CIRCLE          40
# 66   AMT_REQ_CREDIT_BUREAU_YEAR          39
# 44            NONLIVINGAREA_AVG          38
# 10           NAME_FAMILY_STATUS          37
# 36             BASEMENTAREA_AVG          35
# 65    AMT_REQ_CREDIT_BUREAU_QRT          34
# 37  YEARS_BEGINEXPLUATATION_AVG          33
# 2                  FLAG_OWN_CAR          32
# 40                ENTRANCES_AVG          30
# 25   WEEKDAY_APPR_PROCESS_START          30
# 49     OBS_30_CNT_SOCIAL_CIRCLE          30
# 24         REGION_RATING_CLIENT          27
# 0            NAME_CONTRACT_TYPE          25
# 41                FLOORSMAX_AVG          25
# 38              YEARS_BUILD_AVG          24
# 52              FLAG_DOCUMENT_3          23
# 43      NONLIVINGAPARTMENTS_AVG          23
# 11            NAME_HOUSING_TYPE          20
# 29       REG_CITY_NOT_LIVE_CITY          19
# 8              NAME_INCOME_TYPE          18
# 19              FLAG_WORK_PHONE          16
# 61   AMT_REQ_CREDIT_BUREAU_HOUR          14
# 47           WALLSMATERIAL_MODE          14
# 7               NAME_TYPE_SUITE          12
# 4                  CNT_CHILDREN          11
# 60             FLAG_DOCUMENT_18          10
# 3               FLAG_OWN_REALTY           8
# 21                   FLAG_PHONE           7
# 28  LIVE_REGION_NOT_WORK_REGION           6
# 64    AMT_REQ_CREDIT_BUREAU_MON           6
# 22                   FLAG_EMAIL           5
# 45           FONDKAPREMONT_MODE           5
# 46               HOUSETYPE_MODE           4
# 48          EMERGENCYSTATE_MODE           4
# 59             FLAG_DOCUMENT_11           4
# 63   AMT_REQ_CREDIT_BUREAU_WEEK           4
# 54              FLAG_DOCUMENT_5           3
# 55              FLAG_DOCUMENT_6           3
# 30      LIVE_CITY_NOT_WORK_CITY           2
# 62    AMT_REQ_CREDIT_BUREAU_DAY           2
# 57              FLAG_DOCUMENT_8           1
# 18                   FLAG_MOBIL           0
# 20             FLAG_CONT_MOBILE           0
# 27   REG_REGION_NOT_LIVE_REGION           0
# 58              FLAG_DOCUMENT_9           0
# 53              FLAG_DOCUMENT_4           0
# 56              FLAG_DOCUMENT_7           0

# %% [markdown]
# ## **Drop Columns**

# %%
columns = ['FLAG_DOCUMENT_5', 
                   'FLAG_DOCUMENT_6', 
                   'LIVE_CITY_NOT_WORK_CITY', 
                   'AMT_REQ_CREDIT_BUREAU_DAY',
                   'FLAG_DOCUMENT_8',
                   'FLAG_MOBIL',
                   'FLAG_CONT_MOBILE',
                   'REG_REGION_NOT_LIVE_REGION',
                   'FLAG_DOCUMENT_9',
                   'FLAG_DOCUMENT_4',
                   'FLAG_DOCUMENT_7'] 
data = data.drop(columns=columns)

# %% [markdown]
# ### **LGBM**

# %%
X = data.drop('TARGET', axis=1)
y = data['TARGET']

X, y = shuffle(X, y, random_state=random_state)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=random_state)

# %%
model = lgb.LGBMClassifier(boosting_type='gbdt', 
                           num_leaves=31, 
                           max_depth=-1, 
                           learning_rate=0.1, 
                           n_estimators=100,
                           verbose=-1)

model.fit(X_train, y_train)

y_prob = model.predict_proba(X_test)[:, 1]  

auc_score = roc_auc_score(y_test, y_prob)
print(f"AUC Score: {auc_score:.2f}")
# Out:
# AUC Score: 0.75

# %% [markdown]
# ## **Feature Importance**

# %%
# Get feature importance and sort by importance
feature_importance = model.feature_importances_
feature_names = X.columns

# Create a DataFrame to hold feature importance values
importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importance})
importance_df = importance_df.sort_values(by='Importance', ascending=False)

importance_df
# Out:
#                         Feature  Importance
# 30                 EXT_SOURCE_3         256
# 28                 EXT_SOURCE_1         240
# 29                 EXT_SOURCE_2         234
# 13                   DAYS_BIRTH         219
# 6                   AMT_ANNUITY         168
# 14                DAYS_EMPLOYED         157
# 16              DAYS_ID_PUBLISH         135
# 47       DAYS_LAST_PHONE_CHANGE         131
# 15            DAYS_REGISTRATION         119
# 27            ORGANIZATION_TYPE          95
# 5              AMT_INCOME_TOTAL          80
# 12   REGION_POPULATION_RELATIVE          72
# 17                  OWN_CAR_AGE          69
# 9           NAME_EDUCATION_TYPE          58
# 21              OCCUPATION_TYPE          55
# 33  YEARS_BEGINEXPLUATATION_AVG          52
# 24      HOUR_APPR_PROCESS_START          47
# 31               APARTMENTS_AVG          47
# 1                   CODE_GENDER          47
# 38                 LANDAREA_AVG          44
# 45     OBS_30_CNT_SOCIAL_CIRCLE          40
# 46     DEF_30_CNT_SOCIAL_CIRCLE          39
# 32             BASEMENTAREA_AVG          37
# 10           NAME_FAMILY_STATUS          37
# 2                  FLAG_OWN_CAR          36
# 55   AMT_REQ_CREDIT_BUREAU_YEAR          33
# 35               COMMONAREA_AVG          33
# 54    AMT_REQ_CREDIT_BUREAU_QRT          28
# 23   WEEKDAY_APPR_PROCESS_START          27
# 0            NAME_CONTRACT_TYPE          27
# 39      NONLIVINGAPARTMENTS_AVG          27
# 22         REGION_RATING_CLIENT          24
# 34              YEARS_BUILD_AVG          23
# 37                FLOORSMAX_AVG          21
# 36                ENTRANCES_AVG          21
# 48              FLAG_DOCUMENT_3          20
# 11            NAME_HOUSING_TYPE          20
# 4                  CNT_CHILDREN          19
# 8              NAME_INCOME_TYPE          18
# 26       REG_CITY_NOT_LIVE_CITY          17
# 18              FLAG_WORK_PHONE          16
# 51   AMT_REQ_CREDIT_BUREAU_HOUR          15
# 40            NONLIVINGAREA_AVG          15
# 43           WALLSMATERIAL_MODE          13
# 7               NAME_TYPE_SUITE          12
# 50             FLAG_DOCUMENT_18           9
# 19                   FLAG_PHONE           9
# 53    AMT_REQ_CREDIT_BUREAU_MON           9
# 25  LIVE_REGION_NOT_WORK_REGION           6
# 3               FLAG_OWN_REALTY           5
# 44          EMERGENCYSTATE_MODE           5
# 52   AMT_REQ_CREDIT_BUREAU_WEEK           4
# 42               HOUSETYPE_MODE           4
# 41           FONDKAPREMONT_MODE           3
# 49             FLAG_DOCUMENT_11           2
# 20                   FLAG_EMAIL           1
