# %% [markdown]
# # **Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import functions
import importlib
importlib.reload(functions)

import warnings

# %% [markdown]
# # **Display**

# %%
# %matplotlib inline

pd.options.display.max_rows = 300000
pd.options.display.max_columns = 999
pd.options.display.max_colwidth = 500

warnings.filterwarnings("ignore")
warnings.simplefilter(action="ignore", category=FutureWarning)

pd.set_option('display.max_rows', 200)

size = 20

# %% [markdown]
# ## **Colors**

# %%
color_1 = "bisque"
color_2 = "crimson"
color_3 = "orangered"
color_4 = "lightcoral"
color_5 = "royalblue"
color_6 = "indianred"
color_7 = "slategrey"
color_8 = "salmon"
color_9 = "beige"
color_10 = "coral"
color_11 = "grey"
color_12 = "tan"
color_13 = "wheat"
color_14 = "tomato"

# %%
size = 20
params = {
    "font.family": "Times New Roman",
    "font.size": size,
    "axes.labelsize": size,
    "xtick.labelsize": size * 0.75,
    "ytick.labelsize": size * 0.75,
    "figure.titlesize": size * 1.5,
    "axes.titlesize": size * 1.5,
    "axes.titlepad": size,
    "axes.labelpad": size - 10,
    "lines.linewidth": 2,
    "axes.spines.top": False,
    "axes.spines.right": False,
    "axes.spines.left": False,
    "axes.spines.bottom": False,
    "legend.fontsize": size,
    "figure.figsize": (10, 6),
}

# %% [markdown]
# # **Data**

# %% [markdown]
# ## **Load Data**

# %%
train = pd.read_csv(
    r"C:\Users\Dell\Documents\AI\Risk\Data\Data\train.csv",
    index_col=False
)

# %% [markdown]
# ## **Reduce Memory Usage**

# %%
train = functions.reduce_memory_usage(train)
# Out:
# Memory usage of dataframe is 260.42 MB
# Memory usage after optimization is: 88.57 MB
# Decreased by 66.0%

# %% [markdown]
# # **Exploratory Data Analysis**

# %% [markdown]
# ## **Target Disbribution**

# %%
data = train['TARGET'].value_counts()
colors = [color_8, color_9]
labels = [f'Non-Defaulter ({data[1]})', f'Defaulter ({data[0]})']
title = "Target Distribution"

functions.piechart(data, title, colors, labels, size)

# %% [markdown]
# ## **Column Types**

# %%
train.dtypes.value_counts()
# Out:
# float64    59
# int8       26
# object     16
# float32     5
# float16     4
# int32       1
# Name: count, dtype: int64

# %% [markdown]
# ## **Unique Values in Categorical Columns**

# %%
functions.UniqueValues(train)
# Out:
# NAME_CONTRACT_TYPE: 2
# CODE_GENDER: 2
# FLAG_OWN_CAR: 2
# FLAG_OWN_REALTY: 2
# NAME_TYPE_SUITE: 8
# NAME_INCOME_TYPE: 8
# NAME_EDUCATION_TYPE: 5
# NAME_FAMILY_STATUS: 6
# NAME_HOUSING_TYPE: 6
# OCCUPATION_TYPE: 19
# WEEKDAY_APPR_PROCESS_START: 7
# ORGANIZATION_TYPE: 58
# FONDKAPREMONT_MODE: 5
# HOUSETYPE_MODE: 4
# WALLSMATERIAL_MODE: 8
# EMERGENCYSTATE_MODE: 3

# %% [markdown]
# ## **Age**

# %%
data = train
column = 'AGE'
title = 'Age Distribution'
color = color_2
x_label = 'Age in Years'
y_label = 'Frequency'
bins = 30

functions.histplot(data, column, title, color, x_label, y_label, bins)

# %%
plt.figure(figsize=(10,6))

sns.kdeplot(train.loc[train['TARGET'] == 0, 'AGE'], label='Non-Defaulters')
sns.kdeplot(train.loc[train['TARGET'] == 1, 'AGE'], label='Defaulters')

plt.title('Age Distribution');
plt.xlabel('Age in Years');
plt.ylabel('Density');
plt.legend();

# %% [markdown]
# ## **Gender**

# %%
g = sns.catplot(data=train, x='CODE_GENDER', hue='TARGET', kind='count', height=6, aspect=1.5, palette=[color_13, color_14])

for ax in g.axes.flat:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['bottom'].set_visible(False)

plt.title('Gender by Target')
plt.xlabel('Gender')
plt.ylabel('Count')

plt.show()

# %% [markdown]
# ## **Employment**

# %%
data = train
column = 'YEARS_EMPLOYED'
title = 'Employment Distribution'
color = color_3
x_label = 'Employment in Years'
y_label = 'Frequency'
bins = 20

functions.histplot(data, column, title, color, x_label, y_label, bins)

# %%
plt.figure(figsize=(10,6))

sns.kdeplot(train.loc[train['TARGET'] == 0, 'YEARS_EMPLOYED'], label='Non-Defaulters')
sns.kdeplot(train.loc[train['TARGET'] == 1, 'YEARS_EMPLOYED'], label='Defaulters')

plt.title('Employment Distribution');
plt.xlabel('Employment in Years');
plt.ylabel('Density');
plt.legend();

# %% [markdown]
# ## **Family Status**

# %%
g = sns.catplot(data=train, y='NAME_FAMILY_STATUS', hue='TARGET', kind='count', height=6, aspect=1.5, palette=[color_13, color_14])

for ax in g.axes.flat:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['bottom'].set_visible(False)

plt.title('Family Status by Target')
plt.xlabel('Count')
plt.ylabel('Family Status')

plt.show()

# %% [markdown]
# ## **Number of Children**

# %%
g = sns.catplot(data=train, x='CNT_CHILDREN', hue='TARGET', kind='count', height=6, aspect=1.5, palette=[color_13, color_14])

for ax in g.axes.flat:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['bottom'].set_visible(False)

plt.title('Number of Children by Target')
plt.xlabel('Number of Children')
plt.ylabel('Count')

plt.show()

# %% [markdown]
# # **Cars Ownership**

# %%
g = sns.catplot(data=train, x='FLAG_OWN_CAR', hue='TARGET', kind='count', height=6, aspect=1.5, palette=[color_13, color_14])

for ax in g.axes.flat:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['bottom'].set_visible(False)

plt.title('Car Ownership by Target')
plt.xlabel('Count')
plt.ylabel('Car Ownership')

plt.show()

# %% [markdown]
# # **Realty Ownership**

# %%
g = sns.catplot(data=train, x='FLAG_OWN_REALTY', hue='TARGET', kind='count', height=6, aspect=1.5, palette=[color_13, color_14])

for ax in g.axes.flat:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['bottom'].set_visible(False)

plt.title('Realty Ownership by Target')
plt.xlabel('Count')
plt.ylabel('Realty Ownership')

plt.show()

# %% [markdown]
# ## **Contract Type**

# %%
g = sns.catplot(data=train, x='NAME_CONTRACT_TYPE', hue='TARGET', kind='count', height=6, aspect=1.5, palette=[color_13, color_14])

for ax in g.axes.flat:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['bottom'].set_visible(False)

plt.title('Type of Contract by Target')
plt.xlabel('Contract Type')
plt.ylabel('Count')

plt.show()

# %% [markdown]
# ## **Education Type**

# %%
g = sns.catplot(data=train, y='NAME_EDUCATION_TYPE', hue='TARGET', kind='count', height=6, aspect=1.5, palette=[color_13, color_14])

for ax in g.axes.flat:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['bottom'].set_visible(False)

plt.title('Eduction by Target')
plt.xlabel('Count')
plt.ylabel('Eduction Status')

plt.show()

# %% [markdown]
# # **Correlations**

# %% [markdown]
# ## **Label Encoder**

# %%
data_type = 'object'
train = functions.label_encoder(train, data_type)

# %% [markdown]
# ## **Correlation Coefficient**

# %%
corr_matrix = data.corr(numeric_only=True)
corr_matrix['TARGET'].sort_values(ascending=True)
# Out:
# EXT_SOURCE_3                   -0.178926
# EXT_SOURCE_2                   -0.160470
# EXT_SOURCE_1                   -0.155318
# AGE                            -0.078242
# YEARS_LAST_PHONE_CHANGE        -0.055219
# YEARS_ID_PUBLISH               -0.051458
# FLOORSMAX_AVG                  -0.044008
# FLOORSMAX_MEDI                 -0.043773
# FLOORSMAX_MODE                 -0.043231
# YEARS_REGISTRATION             -0.041976
# AMT_GOODS_PRICE                -0.039547
# REGION_POPULATION_RELATIVE     -0.037229
# HOUSETYPE_MODE                 -0.036388
# ELEVATORS_AVG                  -0.034202
# ELEVATORS_MEDI                 -0.033866
# FLOORSMIN_AVG                  -0.033620
# FLOORSMIN_MEDI                 -0.033401
# LIVINGAREA_AVG                 -0.033002
# LIVINGAREA_MEDI                -0.032744
# FLOORSMIN_MODE                 -0.032704
# TOTALAREA_MODE                 -0.032598
# ELEVATORS_MODE                 -0.032135
# NAME_CONTRACT_TYPE             -0.030886
# ORGANIZATION_TYPE              -0.030767
# LIVINGAREA_MODE                -0.030687
# AMT_CREDIT                     -0.030371
# APARTMENTS_AVG                 -0.029502
# APARTMENTS_MEDI                -0.029187
# FONDKAPREMONT_MODE             -0.028958
# FLAG_DOCUMENT_6                -0.028603
# APARTMENTS_MODE                -0.027288
# LIVINGAPARTMENTS_AVG           -0.025034
# LIVINGAPARTMENTS_MEDI          -0.024625
# HOUR_APPR_PROCESS_START        -0.024164
# FLAG_PHONE                     -0.023801
# LIVINGAPARTMENTS_MODE          -0.023396
# BASEMENTAREA_AVG               -0.022747
# YEARS_BUILD_MEDI               -0.022320
# YEARS_BUILD_AVG                -0.022150
# BASEMENTAREA_MEDI              -0.022083
# YEARS_BUILD_MODE               -0.022070
# FLAG_OWN_CAR                   -0.021850
# BASEMENTAREA_MODE              -0.019953
# ENTRANCES_AVG                  -0.019176
# ENTRANCES_MEDI                 -0.019029
# COMMONAREA_MEDI                -0.018575
# COMMONAREA_AVG                 -0.018551
# OCCUPATION_TYPE                -0.017447
# ENTRANCES_MODE                 -0.017391
# COMMONAREA_MODE                -0.016342
# NONLIVINGAREA_AVG              -0.013580
# NONLIVINGAREA_MEDI             -0.013338
# NONLIVINGAREA_MODE             -0.012712
# AMT_ANNUITY                    -0.012698
# AMT_REQ_CREDIT_BUREAU_MON      -0.012460
# LANDAREA_MEDI                  -0.011258
# LANDAREA_AVG                   -0.010887
# LANDAREA_MODE                  -0.010175
# YEARS_BEGINEXPLUATATION_MEDI   -0.010018
# YEARS_BEGINEXPLUATATION_AVG    -0.009756
# YEARS_BEGINEXPLUATATION_MODE   -0.009058
# FLAG_DOCUMENT_8                -0.008042
# FLAG_DOCUMENT_18               -0.007953
# FLAG_OWN_REALTY                -0.006146
# FLAG_DOCUMENT_9                -0.004353
# FLAG_DOCUMENT_11               -0.004230
# NAME_FAMILY_STATUS             -0.004130
# AMT_INCOME_TOTAL               -0.003982
# NONLIVINGAPARTMENTS_AVG        -0.003177
# NONLIVINGAPARTMENTS_MEDI       -0.002758
# FLAG_DOCUMENT_4                -0.002672
# SK_ID_CURR                     -0.002111
# AMT_REQ_CREDIT_BUREAU_QRT      -0.002022
# FLAG_EMAIL                     -0.001759
# NONLIVINGAPARTMENTS_MODE       -0.001557
# FLAG_DOCUMENT_7                -0.001520
# FLAG_DOCUMENT_5                -0.000316
# FLAG_CONT_MOBILE                0.000370
# FLAG_MOBIL                      0.000534
# AMT_REQ_CREDIT_BUREAU_WEEK      0.000787
# AMT_REQ_CREDIT_BUREAU_HOUR      0.000930
# AMT_REQ_CREDIT_BUREAU_DAY       0.002704
# LIVE_REGION_NOT_WORK_REGION     0.002819
# WEEKDAY_APPR_PROCESS_START      0.004000
# REG_REGION_NOT_LIVE_REGION      0.005575
# REG_REGION_NOT_WORK_REGION      0.006941
# NAME_TYPE_SUITE                 0.008441
# OBS_60_CNT_SOCIAL_CIRCLE        0.009027
# OBS_30_CNT_SOCIAL_CIRCLE        0.009136
# CNT_FAM_MEMBERS                 0.009310
# CNT_CHILDREN                    0.019189
# AMT_REQ_CREDIT_BUREAU_YEAR      0.019934
# FLAG_WORK_PHONE                 0.028533
# DEF_60_CNT_SOCIAL_CIRCLE        0.031295
# DEF_30_CNT_SOCIAL_CIRCLE        0.032261
# LIVE_CITY_NOT_WORK_CITY         0.032517
# WALLSMATERIAL_MODE              0.033362
# NAME_HOUSING_TYPE               0.034489
# OWN_CAR_AGE                     0.037611
# EMERGENCYSTATE_MODE             0.041771
# FLAG_DOCUMENT_3                 0.044341
# REG_CITY_NOT_LIVE_CITY          0.044394
# YEARS_EMPLOYED                  0.045978
# FLAG_EMP_PHONE                  0.045984
# NAME_INCOME_TYPE                0.046831
# REG_CITY_NOT_WORK_CITY          0.050992
# NAME_EDUCATION_TYPE             0.054698
# CODE_GENDER                     0.054710
# REGION_RATING_CLIENT            0.058901
# REGION_RATING_CLIENT_W_CITY     0.060895
# TARGET                          1.000000
# Name: TARGET, dtype: float64

# %% [markdown]
# ## **Spearman Correlation**

# %%
functions.spearman_correlation(train, 'TARGET')
# Out:
#                           Feature  Spearman Correlation
# 41                   EXT_SOURCE_2             -0.146675
# 42                   EXT_SOURCE_3             -0.121136
# 16                            AGE             -0.078331
# 94        YEARS_LAST_PHONE_CHANGE             -0.053710
# 19               YEARS_ID_PUBLISH             -0.052535
# 50                  FLOORSMAX_AVG             -0.049234
# 78                 FLOORSMAX_MEDI             -0.049179
# 64                 FLOORSMAX_MODE             -0.048999
# 87                 TOTALAREA_MODE             -0.048475
# 40                   EXT_SOURCE_1             -0.048351
# 54                 LIVINGAREA_AVG             -0.046858
# 82                LIVINGAREA_MEDI             -0.046736
# 68                LIVINGAREA_MODE             -0.046219
# 48                  ELEVATORS_AVG             -0.045987
# 43                 APARTMENTS_AVG             -0.045902
# 76                 ELEVATORS_MEDI             -0.045885
# 71                APARTMENTS_MEDI             -0.045791
# 62                 ELEVATORS_MODE             -0.045533
# 57                APARTMENTS_MODE             -0.045422
# 73   YEARS_BEGINEXPLUATATION_MEDI             -0.044539
# 45    YEARS_BEGINEXPLUATATION_AVG             -0.044498
# 59   YEARS_BEGINEXPLUATATION_MODE             -0.044433
# 49                  ENTRANCES_AVG             -0.043859
# 77                 ENTRANCES_MEDI             -0.043820
# 63                 ENTRANCES_MODE             -0.043236
# 18             YEARS_REGISTRATION             -0.040172
# 56              NONLIVINGAREA_AVG             -0.039905
# 84             NONLIVINGAREA_MEDI             -0.039748
# 70             NONLIVINGAREA_MODE             -0.039646
# 44               BASEMENTAREA_AVG             -0.039103
# 72              BASEMENTAREA_MEDI             -0.039003
# 86                 HOUSETYPE_MODE             -0.038776
# 58              BASEMENTAREA_MODE             -0.038348
# 52                   LANDAREA_AVG             -0.034087
# 80                  LANDAREA_MEDI             -0.034036
# 66                  LANDAREA_MODE             -0.033725
# 74               YEARS_BUILD_MEDI             -0.033481
# 46                YEARS_BUILD_AVG             -0.033463
# 60               YEARS_BUILD_MODE             -0.033447
# 51                  FLOORSMIN_AVG             -0.032702
# 79                 FLOORSMIN_MEDI             -0.032673
# 65                 FLOORSMIN_MODE             -0.032551
# 53           LIVINGAPARTMENTS_AVG             -0.032411
# 81          LIVINGAPARTMENTS_MEDI             -0.032368
# 67          LIVINGAPARTMENTS_MODE             -0.032189
# 104    AMT_REQ_CREDIT_BUREAU_HOUR             -0.032139
# 105     AMT_REQ_CREDIT_BUREAU_DAY             -0.031571
# 9                 AMT_GOODS_PRICE             -0.031409
# 1              NAME_CONTRACT_TYPE             -0.030886
# 15     REGION_POPULATION_RELATIVE             -0.030558
# 39              ORGANIZATION_TYPE             -0.030159
# 106    AMT_REQ_CREDIT_BUREAU_WEEK             -0.030077
# 47                 COMMONAREA_AVG             -0.029407
# 75                COMMONAREA_MEDI             -0.029367
# 108     AMT_REQ_CREDIT_BUREAU_QRT             -0.029319
# 85             FONDKAPREMONT_MODE             -0.029250
# 61                COMMONAREA_MODE             -0.029118
# 107     AMT_REQ_CREDIT_BUREAU_MON             -0.028849
# 98                FLAG_DOCUMENT_6             -0.028603
# 55        NONLIVINGAPARTMENTS_AVG             -0.028359
# 83       NONLIVINGAPARTMENTS_MEDI             -0.028245
# 69       NONLIVINGAPARTMENTS_MODE             -0.028128
# 17                 YEARS_EMPLOYED             -0.025178
# 25                     FLAG_PHONE             -0.023801
# 32        HOUR_APPR_PROCESS_START             -0.022912
# 3                    FLAG_OWN_CAR             -0.021850
# 27                OCCUPATION_TYPE             -0.021368
# 6                AMT_INCOME_TOTAL             -0.018102
# 7                      AMT_CREDIT             -0.017539
# 20                    OWN_CAR_AGE             -0.014336
# 100               FLAG_DOCUMENT_8             -0.008042
# 103              FLAG_DOCUMENT_18             -0.007953
# 4                 FLAG_OWN_REALTY             -0.006146
# 109    AMT_REQ_CREDIT_BUREAU_YEAR             -0.005562
# 101               FLAG_DOCUMENT_9             -0.004353
# 102              FLAG_DOCUMENT_11             -0.004230
# 96                FLAG_DOCUMENT_4             -0.002672
# 0                      SK_ID_CURR             -0.002114
# 13             NAME_FAMILY_STATUS             -0.001818
# 26                     FLAG_EMAIL             -0.001759
# 99                FLAG_DOCUMENT_7             -0.001520
# 97                FLAG_DOCUMENT_5             -0.000316
# 8                     AMT_ANNUITY             -0.000055
# 24               FLAG_CONT_MOBILE              0.000370
# 21                     FLAG_MOBIL              0.000534
# 35    LIVE_REGION_NOT_WORK_REGION              0.002819
# 31     WEEKDAY_APPR_PROCESS_START              0.003747
# 33     REG_REGION_NOT_LIVE_REGION              0.005575
# 34     REG_REGION_NOT_WORK_REGION              0.006941
# 28                CNT_FAM_MEMBERS              0.007012
# 10                NAME_TYPE_SUITE              0.008485
# 92       OBS_60_CNT_SOCIAL_CIRCLE              0.010210
# 90       OBS_30_CNT_SOCIAL_CIRCLE              0.010358
# 5                    CNT_CHILDREN              0.020077
# 23                FLAG_WORK_PHONE              0.028533
# 14              NAME_HOUSING_TYPE              0.029608
# 93       DEF_60_CNT_SOCIAL_CIRCLE              0.032203
# 38        LIVE_CITY_NOT_WORK_CITY              0.032517
# 91       DEF_30_CNT_SOCIAL_CIRCLE              0.033380
# 89            EMERGENCYSTATE_MODE              0.042138
# 88             WALLSMATERIAL_MODE              0.042477
# 95                FLAG_DOCUMENT_3              0.044341
# 36         REG_CITY_NOT_LIVE_CITY              0.044394
# 22                 FLAG_EMP_PHONE              0.045984
# 11               NAME_INCOME_TYPE              0.046505
# 37         REG_CITY_NOT_WORK_CITY              0.050992
# 12            NAME_EDUCATION_TYPE              0.052957
# 2                     CODE_GENDER              0.054710
# 29           REGION_RATING_CLIENT              0.058911
# 30    REGION_RATING_CLIENT_W_CITY              0.060938

# %% [markdown]
# ## **Phi-K Correlation Coefficient Matrix**

# %%
phik_matrix = data.phik_matrix()

feature_target_corr = phik_matrix['TARGET'].drop('TARGET')  
print("Phi-K Correlation of Features with Target:\n", feature_target_corr)

# %% [markdown]
# ## **Sorted Results**

# %%
phik_matrix = train.phik_matrix()

feature_target_corr = phik_matrix['TARGET'].drop('TARGET').sort_values(ascending=False)  

# # Sort the correlations in ascending order
# feature_target_corr_sorted = feature_target_corr.sort_values(ascending=False)

print("Phi-K Correlation of Features with Target (Sorted in Ascending Order):\n", feature_target_corr)
# Out:
# interval columns not set, guessing: ['SK_ID_CURR', 'TARGET', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_ANNUITY', 'AMT_GOODS_PRICE', 'REGION_POPULATION_RELATIVE', 'DAYS_BIRTH', 'DAYS_EMPLOYED', 'DAYS_REGISTRATION', 'DAYS_ID_PUBLISH', 'OWN_CAR_AGE', 'FLAG_MOBIL', 'FLAG_EMP_PHONE', 'FLAG_WORK_PHONE', 'FLAG_CONT_MOBILE', 'FLAG_PHONE', 'FLAG_EMAIL', 'CNT_FAM_MEMBERS', 'REGION_RATING_CLIENT', 'REGION_RATING_CLIENT_W_CITY', 'HOUR_APPR_PROCESS_START', 'REG_REGION_NOT_LIVE_REGION', 'REG_REGION_NOT_WORK_REGION', 'LIVE_REGION_NOT_WORK_REGION', 'REG_CITY_NOT_LIVE_CITY', 'REG_CITY_NOT_WORK_CITY', 'LIVE_CITY_NOT_WORK_CITY', 'EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3', 'APARTMENTS_AVG', 'BASEMENTAREA_AVG', 'YEARS_BEGINEXPLUATATION_AVG', 'YEARS_BUILD_AVG', 'COMMONAREA_AVG', 'ELEVATORS_AVG', 'ENTRANCES_AVG', 'FLOORSMAX_AVG', 'FLOORSMIN_AVG', 'LANDAREA_AVG', 'LIVINGAPARTMENTS_AVG', 'LIVINGAREA_AVG', 'NONLIVINGAPARTMENTS_AVG', 'NONLIVINGAREA_AVG', 'APARTMENTS_MODE', 'BASEMENTAREA_MODE', 'YEARS_BEGINEXPLUATATION_MODE', 'YEARS_BUILD_MODE', 'COMMONAREA_MODE', 'ELEVATORS_MODE', 'ENTRANCES_MODE', 'FLOORSMAX_MODE', 'FLOORSMIN_MODE', 'LANDAREA_MODE', 'LIVINGAPARTMENTS_MODE', 'LIVINGAREA_MODE', 'NONLIVINGAPARTMENTS_MODE', 'NONLIVINGAREA_MODE', 'APARTMENTS_MEDI', 'BASEMENTAREA_MEDI', 'YEARS_BEGINEXPLUATATION_MEDI', 'YEARS_BUILD_MEDI', 'COMMONAREA_MEDI', 'ELEVATORS_MEDI', 'ENTRANCES_MEDI', 'FLOORSMAX_MEDI', 'FLOORSMIN_MEDI', 'LANDAREA_MEDI', 'LIVINGAPARTMENTS_MEDI', 'LIVINGAREA_MEDI', 'NONLIVINGAPARTMENTS_MEDI', 'NONLIVINGAREA_MEDI', 'TOTALAREA_MODE', 'OBS_30_CNT_SOCIAL_CIRCLE', 'DEF_30_CNT_SOCIAL_CIRCLE', 'OBS_60_CNT_SOCIAL_CIRCLE', 'DEF_60_CNT_SOCIAL_CIRCLE', 'DAYS_LAST_PHONE_CHANGE', 'FLAG_DOCUMENT_2', 'FLAG_DOCUMENT_3', 'FLAG_DOCUMENT_4', 'FLAG_DOCUMENT_5', 'FLAG_DOCUMENT_6', 'FLAG_DOCUMENT_7', 'FLAG_DOCUMENT_8', 'FLAG_DOCUMENT_9', 'FLAG_DOCUMENT_10', 'FLAG_DOCUMENT_11', 'FLAG_DOCUMENT_12', 'FLAG_DOCUMENT_13', 'FLAG_DOCUMENT_14', 'FLAG_DOCUMENT_15', 'FLAG_DOCUMENT_16', 'FLAG_DOCUMENT_17', 'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20', 'FLAG_DOCUMENT_21', 'AMT_REQ_CREDIT_BUREAU_HOUR', 'AMT_REQ_CREDIT_BUREAU_DAY', 'AMT_REQ_CREDIT_BUREAU_WEEK', 'AMT_REQ_CREDIT_BUREAU_MON', 'AMT_REQ_CREDIT_BUREAU_QRT', 'AMT_REQ_CREDIT_BUREAU_YEAR']
# Phi-K Correlation of Features with Target (Sorted in Ascending Order):
#  EXT_SOURCE_3                    0.247680
# EXT_SOURCE_1                    0.217846
# EXT_SOURCE_2                    0.213965
# OCCUPATION_TYPE                 0.102846
# DAYS_BIRTH                      0.102395
# ORGANIZATION_TYPE               0.089164
# NAME_INCOME_TYPE                0.084831
# REG_CITY_NOT_WORK_CITY          0.079946
# DAYS_LAST_PHONE_CHANGE          0.073215
# DAYS_EMPLOYED                   0.072094
# FLAG_EMP_PHONE                  0.072087
# REG_CITY_NOT_LIVE_CITY          0.069588
# FLAG_DOCUMENT_3                 0.069525
# DAYS_ID_PUBLISH                 0.067769
# AMT_GOODS_PRICE                 0.059093
# FLOORSMAX_AVG                   0.058673
# FLOORSMAX_MEDI                  0.058445
# FLOORSMAX_MODE                  0.057612
# AMT_CREDIT                      0.056769
# NAME_FAMILY_STATUS              0.056043
# OWN_CAR_AGE                     0.055357
# DAYS_REGISTRATION               0.054592
# NAME_HOUSING_TYPE               0.051107
# LIVE_CITY_NOT_WORK_CITY         0.050956
# NAME_CONTRACT_TYPE              0.048399
# NAME_EDUCATION_TYPE             0.046954
# FLOORSMIN_MEDI                  0.046509
# FLOORSMIN_MODE                  0.046224
# FLOORSMIN_AVG                   0.045679
# ELEVATORS_AVG                   0.045166
# FLAG_DOCUMENT_6                 0.044791
# FLAG_WORK_PHONE                 0.044678
# ELEVATORS_MEDI                  0.044332
# REGION_POPULATION_RELATIVE      0.042570
# ELEVATORS_MODE                  0.041856
# LIVINGAREA_MEDI                 0.041214
# LIVINGAREA_AVG                  0.041186
# TOTALAREA_MODE                  0.040534
# FLAG_PHONE                      0.037258
# LIVINGAREA_MODE                 0.037181
# REGION_RATING_CLIENT_W_CITY     0.036699
# REGION_RATING_CLIENT            0.035450
# APARTMENTS_AVG                  0.035436
# APARTMENTS_MEDI                 0.034588
# HOUR_APPR_PROCESS_START         0.034577
# FLAG_OWN_CAR                    0.034179
# APARTMENTS_MODE                 0.033207
# CODE_GENDER                     0.032921
# YEARS_BUILD_AVG                 0.030880
# YEARS_BUILD_MODE                0.030799
# YEARS_BUILD_MEDI                0.030033
# AMT_ANNUITY                     0.029861
# ENTRANCES_AVG                   0.029747
# ENTRANCES_MEDI                  0.029705
# LIVINGAPARTMENTS_AVG            0.028453
# LIVINGAPARTMENTS_MEDI           0.028107
# WALLSMATERIAL_MODE              0.027739
# LIVINGAPARTMENTS_MODE           0.027456
# ENTRANCES_MODE                  0.027089
# BASEMENTAREA_AVG                0.025519
# BASEMENTAREA_MEDI               0.024063
# COMMONAREA_MEDI                 0.022983
# COMMONAREA_AVG                  0.022767
# AMT_REQ_CREDIT_BUREAU_YEAR      0.021445
# LANDAREA_MEDI                   0.020881
# BASEMENTAREA_MODE               0.020771
# LANDAREA_AVG                    0.020056
# COMMONAREA_MODE                 0.020003
# EMERGENCYSTATE_MODE             0.018600
# DEF_60_CNT_SOCIAL_CIRCLE        0.018315
# FONDKAPREMONT_MODE              0.018009
# FLAG_DOCUMENT_16                0.017927
# FLAG_DOCUMENT_13                0.017812
# LANDAREA_MODE                   0.017189
# NONLIVINGAREA_MEDI              0.016238
# CNT_FAM_MEMBERS                 0.016143
# NONLIVINGAREA_AVG               0.016029
# AMT_REQ_CREDIT_BUREAU_MON       0.015601
# NONLIVINGAREA_MODE              0.014609
# FLAG_DOCUMENT_14                0.014416
# NONLIVINGAPARTMENTS_MODE        0.013267
# CNT_CHILDREN                    0.012698
# FLAG_DOCUMENT_8                 0.012271
# FLAG_DOCUMENT_18                0.012056
# NONLIVINGAPARTMENTS_AVG         0.010533
# REG_REGION_NOT_WORK_REGION      0.010486
# FLAG_DOCUMENT_15                0.009587
# FLAG_OWN_REALTY                 0.009212
# DEF_30_CNT_SOCIAL_CIRCLE        0.009083
# NAME_TYPE_SUITE                 0.008746
# REG_REGION_NOT_LIVE_REGION      0.008207
# HOUSETYPE_MODE                  0.007787
# NONLIVINGAPARTMENTS_MEDI        0.007572
# YEARS_BEGINEXPLUATATION_MODE    0.007380
# FLAG_DOCUMENT_2                 0.006475
# FLAG_DOCUMENT_9                 0.006056
# FLAG_DOCUMENT_11                0.005843
# WEEKDAY_APPR_PROCESS_START      0.005163
# YEARS_BEGINEXPLUATATION_MEDI    0.005025
# FLAG_DOCUMENT_21                0.004497
# FLAG_DOCUMENT_17                0.003790
# YEARS_BEGINEXPLUATATION_AVG     0.003772
# AMT_INCOME_TOTAL                0.003358
# LIVE_REGION_NOT_WORK_REGION     0.003343
# AMT_REQ_CREDIT_BUREAU_DAY       0.003309
# FLAG_DOCUMENT_4                 0.001394
# SK_ID_CURR                      0.000000
# FLAG_MOBIL                      0.000000
# FLAG_CONT_MOBILE                0.000000
# FLAG_EMAIL                      0.000000
# OBS_60_CNT_SOCIAL_CIRCLE        0.000000
# FLAG_DOCUMENT_5                 0.000000
# OBS_30_CNT_SOCIAL_CIRCLE        0.000000
# FLAG_DOCUMENT_10                0.000000
# FLAG_DOCUMENT_7                 0.000000
# FLAG_DOCUMENT_19                0.000000
# FLAG_DOCUMENT_12                0.000000
# AMT_REQ_CREDIT_BUREAU_HOUR      0.000000
# FLAG_DOCUMENT_20                0.000000
# AMT_REQ_CREDIT_BUREAU_WEEK      0.000000
# AMT_REQ_CREDIT_BUREAU_QRT       0.000000
# Name: TARGET, dtype: float64

# %% [markdown]
# ## **Drop Collinear Features**

# %%
dcf = DropCorrelatedFeatures(threshold=0.7)
data = dcf.fit_transform(data)

# %% [markdown]
# ## **New Data**

# %%
data.shape
# Out:
# (307511, 78)

# %% [markdown]
# ## **Mutual Information Plot**

# %% [markdown]
# This plot shows the predicitve power of each feature.

# %%
features = data.drop(columns=['TARGET'])
target = data['TARGET']

features = features.dropna()
target = target[features.index] 
features = pd.get_dummies(features, drop_first=True)

mi_scores = mutual_info_classif(features, target)
functions.create_plot_mi_scores(features, mi_scores)
